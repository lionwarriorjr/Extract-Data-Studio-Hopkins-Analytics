# %%
import csv
import os
import pandas as pd

desc_filename = os.path.join(os.getcwd(), '2017_data.csv')
X = pd.read_csv(desc_filename, encoding = "latin1")
X.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (22,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    pitcher  batter  num  b  s  o  start_tfs        start_tfs_zulu stand  \
# 0   435221  488862    1  2  3  1    10807.0  2017-04-02T01:08:07Z     R
# 1   435221  488862    1  2  3  1    10807.0  2017-04-02T01:08:07Z     R
# 2   435221  488862    1  2  3  1    10807.0  2017-04-02T01:08:07Z     R
# 3   435221  488862    1  2  3  1    10807.0  2017-04-02T01:08:07Z     R
# 4   435221  488862    1  2  3  1    10807.0  2017-04-02T01:08:07Z     R
#
#   b_height       ...       pitch_type    Date team_id_batter team_id_pitcher  \
# 0    2-Jun       ...               FF  4/1/17         anamlb          lanmlb
# 1    2-Jun       ...               FC  4/1/17         anamlb          lanmlb
# 2    2-Jun       ...               FC  4/1/17         anamlb          lanmlb
# 3    2-Jun       ...               FC  4/1/17         anamlb          lanmlb
# 4    2-Jun       ...               FF  4/1/17         anamlb          lanmlb
#
#   outs_when_up  home_team_runs_when_up  away_team_runs_when_up     bb_type  \
# 0            0                       0                       0  strike_out
# 1            0                       0                       0  strike_out
# 2            0                       0                       0  strike_out
# 3            0                       0                       0  strike_out
# 4            0                       0                       0  strike_out
#
#   at_bat_id  in_strike_zone
# 0         1               0
# 1         1               0
# 2         1               1
# 3         1               1
# 4         1               0
#
# [5 rows x 80 columns]

# %%
X.columns
# Out:
# Index(['pitcher', 'batter', 'num', 'b', 's', 'o', 'start_tfs',
#        'start_tfs_zulu', 'stand', 'b_height', 'p_throws', 'atbat_des',
#        'atbat_des_es', 'event', 'score', 'home_team_runs', 'away_team_runs',
#        'url', 'inning_side', 'inning', 'next_', 'event2', 'event3',
#        'batter_name', 'pitcher_name', 'event4', 'gameday_link', 'date',
#        'event_num', 'event_es', 'play_guid', 'event2_es', 'end_tfs_zulu',
#        'event3_es', 'des', 'id', 'on_1b', 'on_2b', 'on_3b', 'type', 'x', 'y',
#        'x0', 'y0', 'z0', 'px', 'pz', 'start_speed', 'end_speed', 'pfx_x',
#        'pfx_z', 'tfs', 'tfs_zulu', 'sz_top', 'sz_bot', 'vx0', 'vy0', 'vz0',
#        'ax', 'ay', 'az', 'break_y', 'break_angle', 'break_length',
#        'type_confidence', 'zone', 'nasty', 'spin_dir', 'spin_rate', 'count',
#        'pitch_type', 'Date', 'team_id_batter', 'team_id_pitcher',
#        'outs_when_up', 'home_team_runs_when_up', 'away_team_runs_when_up',
#        'bb_type', 'at_bat_id', 'in_strike_zone'],
#       dtype='object')

# %%
with open(desc_filename,'r', encoding='latin1') as csvinput:
    with open('2017_updated1.csv', 'w', encoding='latin1') as csvoutput:
        writer = csv.writer(csvoutput, lineterminator='\n')
        reader = csv.reader(csvinput)

        all = []
        row = next(reader)
        row.append('outs_when_up')
        all.append(row)
        outs = 0
        second_outs = 0
        inning = "top"
        batter = 0
        for row in reader:
            if outs != row[5]:
                if row[18] != inning:
                    outs = 0
                    inning = row[18]
                second_outs = outs
            elif batter != row[1]:
                second_outs = outs
            row.append(str(second_outs))
            all.append(row)
            outs = row[5]
            batter = row[1]

        writer.writerows(all)

# %%
with open('2017_updated1.csv','r', encoding='latin1') as csvinput:
    with open('2017_updated2.csv', 'w', encoding='latin1') as csvoutput:
        writer = csv.writer(csvoutput, lineterminator='\n')
        reader = csv.reader(csvinput)

        all = []
        row = next(reader)
        row.append('home_team_runs_when_up')
        row.append('away_team_runs_when_up')
        all.append(row)
        home = 0
        away = 0
        second_home = 0
        second_away = 0
        batter = 0
        for row in reader:
            if batter != row[1]:
                if second_home != row[15]:
                    second_home = home
                if second_away != row[16]:
                    second_away = away
            row.append(str(second_home))
            row.append(str(second_away))
            all.append(row)
            home = row[15]
            away = row[16]
            batter = row[1]

        writer.writerows(all)

# %%
with open('2017_updated2.csv','r', encoding='latin1') as csvinput:
    with open('2017_updated3.csv', 'w', encoding='latin1') as csvoutput:
        writer = csv.writer(csvoutput, lineterminator='\n')
        reader = csv.reader(csvinput)

        all = []
        row = next(reader)
        row.append('bb_type')
        all.append(row)
        for row in reader:
            if "sac fly" in row[13].lower():
                row.append("sac_fly")
            elif "sac bunt" in row[13].lower():
                row.append("sac_bunt")
            elif "fly ball" in row[11].lower():
                row.append("fly_ball")
            elif "ground ball" in row[11].lower():
                row.append("ground_ball")
            elif "line drive" in row[11].lower():
                row.append("line_drive")
            elif "popup" in row[11].lower():
                row.append("popup")
            elif "flies out" in row[11].lower():
                row.append("fly_out")
            elif "grounds out" in row[11].lower():
                row.append("grounds_out")
            elif "lines out" in row[11].lower():
                row.append("lines_out")
            elif "pops out" in row[11].lower():
                row.append("pop_out")
            elif "walks" in row[11].lower():
                row.append("walk")
            else:
                row.append("strike_out")
            all.append(row)

        writer.writerows(all)

# %%
with open('2017_updated3.csv','r', encoding='latin1') as csvinput:
    with open('2017_updated4.csv', 'w', encoding='latin1') as csvoutput:
        writer = csv.writer(csvoutput, lineterminator='\n')
        reader = csv.reader(csvinput)

        all = []
        row = next(reader)
        row.append('at_bat_id')
        all.append(row)
        batter = 0
        id_ = 0
        for row in reader:
            if batter != row[4]:
                id_+=1
                batter = row[4]
            row.append(str(id_))
            all.append(row)

        writer.writerows(all)

# %%
with open('2017_updated4.csv','r', encoding='latin1') as csvinput:
    with open('2017_updated_final.csv', 'w', encoding='latin1') as csvoutput:
        writer = csv.writer(csvoutput, lineterminator='\n')
        reader = csv.reader(csvinput)

        all = []
        row = next(reader)
        row.append('in_strike_zone')
        all.append(row)
        strike = 0
        for row in reader:
            if row[45] == "NA":
                strike = 0
            elif (float(row[45]) > 0.8391667) or (float(row[45]) < -0.8391667):
                strike = 0
            elif (float(row[46]) < float(row[54])) or (float(row[46]) > float(row[53])):
                strike = 0
            else:
                strike = 1
            row.append(str(strike))
            all.append(row)

        writer.writerows(all)

# %%
os.remove("2017_updated1.csv")
os.remove("2017_updated2.csv")
os.remove("2017_updated3.csv")
os.remove("2017_updated4.csv")

# %%
with open(desc_filename,'r', encoding='latin1') as csvinput:
    with open('2017_updated_test1.csv', 'w', encoding='latin1') as csvoutput:
        writer = csv.writer(csvoutput, lineterminator='\n')
        reader = csv.reader(csvinput)

        all = []
        row = next(reader)
        row.append('outs_when_up')
        all.append(row)
        outs = 0
        second_outs = 0
        inning = "top"
        batter = 0
        for row in reader:
            if outs != row[5]:
                if row[18] != inning:
                    outs = 0
                    inning = row[18]
                second_outs = outs
            elif batter != row[1]:
                second_outs = outs
            row.append(str(second_outs))
            all.append(row)
            outs = row[5]
            batter = row[1]

        writer.writerows(all)

# %%
with open('2017_updated_test1.csv','r', encoding='latin1') as csvinput:
    with open('2017_updated_test2.csv', 'w', encoding='latin1') as csvoutput:
        writer = csv.writer(csvoutput, lineterminator='\n')
        reader = csv.reader(csvinput)

        all = []
        row = next(reader)
        row.append('bb_type')
        all.append(row)
        for row in reader:
            if "sac fly" in row[13].lower():
                row.append("sac_fly")
            elif "sac bunt" in row[13].lower():
                row.append("sac_bunt")
            elif "fly ball" in row[11].lower():
                row.append("fly_ball")
            elif "ground ball" in row[11].lower():
                row.append("ground_ball")
            elif "line drive" in row[11].lower():
                row.append("line_drive")
            elif "popup" in row[11].lower():
                row.append("popup")
            elif "flies out" in row[11].lower():
                row.append("fly_out")
            elif "grounds out" in row[11].lower():
                row.append("grounds_out")
            elif "lines out" in row[11].lower():
                row.append("lines_out")
            elif "pops out" in row[11].lower():
                row.append("pop_out")
            elif "walks" in row[11].lower():
                row.append("walk")
            else:
                row.append("strike_out")
            all.append(row)

        writer.writerows(all)

# %%
with open('2017_updated_test2.csv','r', encoding='latin1') as csvinput:
    with open('2017_updated_test3.csv', 'w', encoding='latin1') as csvoutput:
        writer = csv.writer(csvoutput, lineterminator='\n')
        reader = csv.reader(csvinput)

        all = []
        row = next(reader)
        row.append('at_bat_id')
        all.append(row)
        batter = 0
        id_ = 0
        for row in reader:
            if batter != row[1]:
                id_+=1
                batter = row[1]
            row.append(str(id_))
            all.append(row)

        writer.writerows(all)

# %%
with open('2017_updated_test3.csv','r', encoding='latin1') as csvinput:
    with open('2017_updated_final.csv', 'w', encoding='latin1') as csvoutput:
        writer = csv.writer(csvoutput, lineterminator='\n')
        reader = csv.reader(csvinput)

        all = []
        row = next(reader)
        row.append('in_strike_zone')
        all.append(row)
        strike = 0
        for row in reader:
            if row[45] == "NA":
                strike = 0
            elif (float(row[45]) > 0.8391667) or (float(row[45]) < -0.8391667):
                strike = 0
            elif (float(row[46]) < float(row[54])) or (float(row[46]) > float(row[53])):
                strike = 0
            else:
                strike = 1
            row.append(str(strike))
            all.append(row)

        writer.writerows(all)

# %%
os.remove("2017_updated_test1.csv")
os.remove("2017_updated_test2.csv")
#os.remove("2017_updated_test3.csv")
#os.remove("2017_updated4.csv")

# %%
#with open('2017_updated2.csv','r') as csvinput:
    #with open('2017_updated3.csv', 'w') as csvoutput:
        #writer = csv.writer(csvoutput, lineterminator='\n')
        #reader = csv.reader(csvinput)

        #all = []
        #row = next(reader)
        #row.append('bb_type')
        #all.append(row)
        #for row in reader:
            #if "sac fly" in row[13].lower():
                #row.append("sac_fly")
            #elif "sac bunt" in row[13].lower():
                #row.append("sac_bunt")
            #elif "fly ball" in row[11].lower():
                #row.append("fly_ball")
            #elif "ground ball" in row[11].lower():
                #row.append("ground_ball")
            #elif "line drive" in row[11].lower():
                #row.append("line_drive")
            #elif "popup" in row[11].lower():
                #row.append("popup")
            #elif "flies out" in row[11].lower():
                #row.append("fly_out")
            #elif "grounds out" in row[11].lower():
                #row.append("grounds_out")
            #elif "lines out" in row[11].lower():
                #row.append("lines_out")
            #elif "pops out" in row[11].lower():
                #row.append("pop_out")
            #elif "walks" in row[11].lower():
                #row.append("walk")
            #else:
                #row.append("strike_out")
            #all.append(row)

        #writer.writerows(all)

with open('2017_updated2.csv','r') as csvinput:
    with open('2017_updated3.csv', 'w') as csvoutput:
        writer = csv.writer(csvoutput, lineterminator='\n')
        reader = csv.reader(csvinput)

        all = []
        row = next(reader)
        row.append('at_bat_id')
        all.append(row)
        batter = 0
        id_ = 0
        for row in reader:
            if batter != row[1]:
                id_+=1
                batter = row[1]
            row.append(str(id_))
            all.append(row)

        writer.writerows(all)


#with open('2017_updated4.csv','r') as csvinput:
    #with open('2017_updated.csv', 'w') as csvoutput:
        #writer = csv.writer(csvoutput, lineterminator='\n')
        #reader = csv.reader(csvinput)

        #all = []
        #row = next(reader)
        #row.append('in_strike_zone')
        #all.append(row)
        #strike = 0
        #for row in reader:
            #if row[45] == "NA":
                #strike = 0
            #elif (float(row[45]) > 0.8391667) or (float(row[45]) < -0.8391667):
                #strike = 0
            #elif (float(row[46]) < float(row[54])) or (float(row[46]) > float(row[53])):
                #strike = 0
            #else:
                #strike = 1
            #row.append(str(strike))
            #all.append(row)

        #writer.writerows(all)
        
os.remove("2017_updated1.csv")
os.remove("2017_updated2.csv")
#os.remove("2017_updated3.csv")
#os.remove("2017_updated4.csv")

# %%
df = pd.read_csv("2017_statcast_subset.csv")
df = df[df['batter_name'] == 'Bryce Harper']
print(df.shape)
df.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (3,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (1953, 60)
#         batter  pitcher   pitcher_name   batter_name  num b_height p_throws  \
# 393903  547180   592662     Robbie Ray  Bryce Harper   37      6-3        L
# 393904  547180   623184    Scott Oberg  Bryce Harper   67      6-3        R
# 393905  547180   572831     Josh Edgin  Bryce Harper   82      6-3        L
# 393906  547180   112526  Bartolo Colon  Bryce Harper   24      6-3        R
# 393907  547180   527054  Julio Teheran  Bryce Harper   35      6-3        R
#
#                           gameday_link             event  inning  \
# 393903  gid_2017_07_23_wasmlb_arimlb_1            Flyout       5
# 393904  gid_2017_04_25_wasmlb_colmlb_1         Groundout       7
# 393905  gid_2017_04_28_nynmlb_wasmlb_1  Grounded Into DP       9
# 393906  gid_2017_05_20_wasmlb_atlmlb_1            Single       4
# 393907  gid_2017_04_19_wasmlb_atlmlb_1       Intent Walk       4
#
#              ...       spin_rate count  pitch_type        Date  outs_when_up  \
# 393903       ...        2398.539   0-0          FF  2017-07-23           6-2
# 393904       ...         493.461   1-0          SL  2017-04-25             0
# 393905       ...         748.377   0-0          SL  2017-04-28           6-2
# 393906       ...        1563.165   2-2          FT  2017-05-20           6-5
# 393907       ...        1415.940   1-1          FF  2017-04-19             0
#
#        home_team_runs_when_up away_team_runs_when_up  at_bat_id  \
# 393903                      0                      5     113259
# 393904                      5                     14      23387
# 393905                      5                      7      26073
# 393906                      2                      0      49360
# 393907                      3                      6      17464
#
#         team_id_pitcher  team_id_batter
# 393903           arimlb          wasmlb
# 393904           colmlb          wasmlb
# 393905           nynmlb          wasmlb
# 393906           nynmlb          wasmlb
# 393907           atlmlb          wasmlb
#
# [5 rows x 60 columns]

# %%
import collections
calc = pd.DataFrame([""])
print(df.shape)
if df.shape[0] > 0:
    pitches = collections.Counter()
    batter_up = -1
    event = ""
    second_last_at_bat_pitch_type = ""
    last_at_bat_pitch_type = ""
    for index, row in df.iterrows():
        # new batter, we want to look at what happened at last pitch
        if batter_up != row["at_bat_id"]:
            #print(row['event'])
            # we only care if this guy struck out
            if event in ["Flyout","Grounded Into DP", "Groundout", "Lineout", "Pop ut", "Strikeout"]:
                power_sequence = str(second_last_at_bat_pitch_type) + " " + str(last_at_bat_pitch_type)
                # if we've seen this sequence before, we incrememnt by 1.
                # if we haven't, default is 0
                pitches[power_sequence]+=1
            second_last_at_bat_pitch_type = ""
            last_at_bat_pitch_type = ""
            event = ""
            batter_up = row["at_bat_id"]
        else:
            # we want last two at bats at all times in case they are the last pitch
            # puts them into zone based on four squares - zone 1-4.
            # possbile TODO: account for right/left hitters
            x = row["px"]
            z = row["pz"]
            if x < -1.25 or x > 1.25:
                horiz = 3
            if -1.25 < x < 0:
                horiz = 1
            if 0 < x < 1.25:
                horiz = 2
            if z<0.75 or z>3.58:
                vert = 3
            if 0.75 < z < 2.176:
                vert = 1
            if 2.17 < z < 3.58:
                vert = 2
            if (horiz,vert) == (1,1):
                zone = 'Zone 3'
            if (horiz,vert) == (2,1):
                zone = 'Zone 4'
            if (horiz,vert) == (1,2):
                zone = 'Zone 2'
            if (horiz,vert) == (2,2):
                zone = 'Zone 1'
            if horiz == 3 or vert == 3:
                zone = "ball"
            second_last_at_bat_pitch_type = last_at_bat_pitch_type
            last_at_bat_pitch_type = str(row["pitch_type"]) + " " + str(zone)
            event = row["event"]
    if pitches:
        power_sequence = str(pitches.most_common(1)[0][0])
        calc = pd.DataFrame([power_sequence])
        print(calc)
# Out:
# (1953, 60)
#             0
# 0   CU Zone 3

# %%
df.at_bat_id
# Out:
# 393903    113259
# 393904     23387
# 393905     26073
# 393906     49360
# 393907     17464
# 393908     71232
# 393909     88385
# 393910    187168
# 393911     19433
# 393912     56211
# 393913     90556
# 393914     50550
# 393915    183906
# 393916    127920
# 393917     88409
# 393918     29739
# 393919     46258
# 393920      5364
# 393921    187185
# 393922    113225
# 393923     88385
# 393924     65724
# 393925     80854
# 393926     38195
# 393927     81957
# 393928     86602
# 393929    103331
# 393930     13248
# 393931     71232
# 393932     98004
#            ...
# 395826     48309
# 395827     88409
# 395828    127867
# 395829     10290
# 395830     56196
# 395831    187584
# 395832    103396
# 395833     66870
# 395834     23335
# 395835     38414
# 395836     26073
# 395837     88369
# 395838    105721
# 395839    121314
# 395840     96426
# 395841    186134
# 395842     14243
# 395843     74607
# 395844     78806
# 395845    103348
# 395846     10310
# 395847     47178
# 395848    187885
# 395849     80818
# 395850    106730
# 395851     69914
# 395852     29739
# 395853     98866
# 395854     38430
# 395855    187831
# Name: at_bat_id, Length: 1953, dtype: int64

# %%
df.event
# Out:
# 393903              Flyout
# 393904           Groundout
# 393905    Grounded Into DP
# 393906              Single
# 393907         Intent Walk
# 393908                Walk
# 393909              Flyout
# 393910           Groundout
# 393911              Flyout
# 393912           Strikeout
# 393913                Walk
# 393914           Strikeout
# 393915    Grounded Into DP
# 393916           Strikeout
# 393917           Strikeout
# 393918              Flyout
# 393919           Groundout
# 393920           Strikeout
# 393921           Groundout
# 393922              Single
# 393923              Flyout
# 393924           Strikeout
# 393925                Walk
# 393926         Intent Walk
# 393927           Strikeout
# 393928              Single
# 393929                Walk
# 393930           Groundout
# 393931                Walk
# 393932              Flyout
#                 ...
# 395826           Strikeout
# 395827           Strikeout
# 395828           Strikeout
# 395829           Strikeout
# 395830     Fielders Choice
# 395831           Groundout
# 395832           Groundout
# 395833           Strikeout
# 395834                Walk
# 395835             Pop Out
# 395836    Grounded Into DP
# 395837             Lineout
# 395838             Pop Out
# 395839           Strikeout
# 395840                Walk
# 395841                Walk
# 395842              Single
# 395843              Flyout
# 395844             Lineout
# 395845            Home Run
# 395846             Lineout
# 395847           Strikeout
# 395848           Strikeout
# 395849             Lineout
# 395850            Home Run
# 395851              Single
# 395852              Flyout
# 395853    Grounded Into DP
# 395854              Double
# 395855              Single
# Name: event, Length: 1953, dtype: object
